# %% [markdown]
# <a href="https://colab.research.google.com/github/samsarkar184/ML-Projects/blob/main/PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris



iris=load_iris()
print(iris.data.shape)
X=iris.data
y=iris.target
X_test,
# Out:
# (150, 4)
